# %%
# !pip install tweepy

# %%
import tweepy

# %%
consumer_key = "R1TyjKSNWMtmhPg1tSJ7ApVCI"
consumer_secret = "TVmtQOGOqNJqXjs9e3ptkFsqtpWqJNSMZnwJoRkWe26GfYHNjc"
access_token = "380900606-Vjujg248bF0xQub99t6PISphyW7Lqu5A0VORgusN"
access_token_secret = "ZTaCyhjd4W8Nea4hTJkNNX3pv9eC5OECXKad6LswjEVPk"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
import time

# %%
tweets_list20 = []
text_querries = ['teri biwi','chacha ji','','teri maa','tera baap','pitaji','pappu','galat baat hai','','gareeb','mashaallah','sharam kar','maa ke laude','maa ki chut','muth maar','laundiya','laundey','chinnatey','ro mat','farak nahi padta','mu mein lele','meh me le le','badtameezi','chut maari ke','madar chod','madarchod','behenchod','bhenchod','laanat hai','ma ka bhosda','maa ki choot','behen ki chut','badnaam','aukaad mein reh','jai shree ram','maa chuda','bhaad mei jaa','bhaad mein ja','gaand mara','dekha jayega']
for text_query in text_querries:
  count = 1000
  try:
  # Pulling individual tweets from query
      for tweet in api.search(q=text_query, count=count):
  # Adding to list that contains all tweets
        tweets_list20.append((tweet.created_at,tweet.id,tweet.text))
  except BaseException as e:
      print('failed on_status,',str(e))
      time.sleep(3)

# %%
df.head()

# %% [markdown]
# # Better Than Tweepy

# %%
# !pip install GetOldTweets3

# %%
import GetOldTweets3 as got

# %%
# !GetOldTweets3 --querysearch "bakchod" --maxtweets 10
# Out:
# ...
# An error occured during an HTTP request: HTTP Error 404: Not Found
# Try to open in browser: https://twitter.com/search?q=bakchod&src=typd
#
# Done. Output file generated "output_got.csv".

# %%
b = ['chootiye','chutiye','bakchod','laude']

# %%
import time
from datetime import datetime, date, timedelta
text_tweets10 = []
text_querriess = b
for text_query in text_querriess:
  try:
    count = 4300
    # Creation of query object
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setMaxTweets(count)
    # Creation of list that contains all tweets
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    # Creating list of chosen tweet data
    text_tweets10.append([tweet.text for tweet in tweets])
    time.sleep(300)
  except SocketError as e:
    if e.errno != errno.ECONNRESET:
        raise # Not error we are looking for
    pass # Handle error here.

# %%
text_tweets10
# Out:
# []

# %%
import time
from datetime import datetime, date, timedelta
text_tweets10 = []
text_querriess = b
for text_query in text_querriess[443:]:
  count = 4300
  # Creation of query object
  tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setMaxTweets(count)
  # Creation of list that contains all tweets
  tweets = got.manager.TweetManager.getTweets(tweetCriteria)
  # Creating list of chosen tweet data
  text_tweets10.append([tweet.text for tweet in tweets])
  time.sleep(250)

# %%
import pandas as pd

# %%
df = pd.DataFrame(text_tweets10)

# %%
df.values
# Out:
# array([['Alya bhai congress karta to middle class na loko berojgar che Roj ketla loko nokri dhandha vagar aatmahatya kare che e nathi dekhatu???? Andh bhakt etli pan bhakti na kar k political party sivay biju kai dekhatu j band thai jay ',
#         '96% Overwhelmingly Positive Reviews! Grab a friend and get in on the co-op FPS action!',
#         'Phir bacha hi kya hai..aatmanirbhar bana raho ya aatmahatya krva rahe ho',
#         ...,
#         '@BJP4India aur @narendramodi ki sarkaar me to 3 sal me he bacche bhuke mar re hai aur Kisan aatmahatya kar rahe hai.berozgar bhatak raha hai',
#         'Hait kaatar le ho aatmahatya garne bhaneko',
#         'Ani shetkari aatmahatya zalya UPA chya kalat.Tevha devala ani nisargala dosh. Nisarga pudhe tar ajit pawar cha sinchan pan fail gela'],
#        ['انا ايضا تؤذيني مزاجيتي ....،',
#         '96% Overwhelmingly Positive Reviews! Grab a friend and get in on the co-op FPS action!',
# ...

# %%
df.to_csv('abusiveB29.csv')

# %%
dff = pd.read_csv('hindii.csv')

# %%
dff.to_csv('hindii.csv')

# %%
ss =list(dff.word)

# %%
ss

# %% [markdown]
# # Transliteration

# %%
# !git clone https://github.com/libindic/indic-trans.git
# Out:
# Cloning into 'indic-trans'...
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 2207 (delta 0), reused 0 (delta 0), pack-reused 2206
# Receiving objects: 100% (2207/2207), 516.51 MiB | 23.17 MiB/s, done.
# Resolving deltas: 100% (1094/1094), done.
# Checking out files: 100% (718/718), done.

# %%
cd indic-trans/
# Out:
# /content/indic-trans

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 112kB 1.7MB/s
# ...

# %%
# !python3 setup.py build_ext --inplace
# Out:
# Compiling indictrans/_decode/beamsearch.pyx because it changed.
# Compiling indictrans/_decode/viterbi.pyx because it changed.
# [1/2] Cythonizing indictrans/_decode/beamsearch.pyx
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/indic-trans/indictrans/_decode/beamsearch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# [2/2] Cythonizing indictrans/_decode/viterbi.pyx
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/indic-trans/indictrans/_decode/viterbi.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# running build_ext
# building 'indictrans._decode.beamsearch' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# ...

# %%
from indictrans import Transliterator
trn = Transliterator(source='hin', target='eng', build_lookup=True)

# %%
with open('/content/final_stopwords.txt', 'r') as f:
    sents = [line.strip() for line in f]

# %%
with open('/content/english common words.txt', 'r') as f:
    sents2 = [line.strip() for line in f]

# %%
for n, i in enumerate(sents):
  sents[n] = trn.transform(i)

# %%
sentsss = sents+sents2

# %%
sents2
# Out:
# ['\ufeffa',
#  'abandon',
#  'ability',
#  'able',
#  'abortion',
#  'about',
#  'above',
#  'abroad',
#  'absence',
#  'absolute',
#  'absolutely',
#  'absorb',
#  'abuse',
#  'academic',
#  'accept',
#  'access',
#  'accident',
#  'accompany',
#  'accomplish',
#  'according',
#  'account',
#  'accurate',
#  'accuse',
#  'achieve',
#  'achievement',
#  'acid',
#  'acknowledge',
#  'acquire',
#  'across',
#  'act',
#  'action',
#  'active',
#  'activist',
#  'activity',
#  'actor',
#  'actress',
#  'actual',
#  'actually',
#  'ad',
#  'adapt',
#  'add',
#  'addition',
#  'additional',
#  'address',
#  'adequate',
#  'adjust',
#  'adjustment',
#  'administration',
#  'administrator',
#  'admire',
#  'admission',
#  'admit',
#  'adolescent',
#  'adopt',
#  'adult',
#  'advance',
#  'advanced',
#  'advantage',
#  'adventure',
#  'advertising',
#  'advice',
#  'advise',
#  'adviser',
#  'advocate',
#  'affair',
#  'affect',
#  'afford',
#  'afraid',
#  'African',
#  'African-American',
# ...

# %%
sents
# Out:
# ['main',
#  'mujhako',
#  'meraa',
#  'apane aap ko',
#  'hamane',
#  'hamaara',
#  'apana',
#  'ham',
#  'aap',
#  'aapkaa',
#  'tumhaara',
#  'apane aap',
#  'swayan',
#  'vah',
#  'ise',
#  'uske',
#  'khud ko',
#  'ki vah',
#  'uski',
#  'uskaa',
#  'khud hi',
#  'yah',
#  'iske',
#  'unhone',
#  'apane',
#  'kya',
#  'jo',
#  'kise',
#  'kisko',
#  'ki',
#  'ye',
#  'hoon',
#  'hota he',
#  'rahe',
#  'thi',
#  'the',
#  'hona',
#  'gaya',
#  'kiya ja rahaa he',
#  'kiya he',
#  'he',
#  'pada',
#  'hone',
#  'karnaa',
#  'karata he',
#  'kiya',
#  'rahi',
#  'ek',
#  'lekin',
#  'agar',
#  'yaa',
#  'kyunki',
#  'jaisaa',
#  'jab tak',
#  'jabaki',
#  'kii',
#  'par',
#  'dwaara',
#  'ke liye',
#  'saath',
#  'ke bare main',
#  'khilaaf',
#  'bich',
#  'main',
#  'ke madhyam se',
#  'dauraan',
#  'se pehle',
#  'ke baad',
#  'upar',
#  'neeche',
#  'ko',
#  'se',
#  'tak',
#  'se neeche',
#  'karne main',
#  'nikal',
#  'band',
#  'se adhik',
#  'tahat',
#  'dubaara',
# ...

# %%
import pandas as pd

# %%
abdf = pd.read_csv('/content/agr_hi_train.csv')

# %%
abdf.columns= ['id','review','label']

# %%
 vocab = list(abdf['review'].str.split(' ', expand=True).stack().unique())

# %%
len(vocab)
# Out:
# 55352

# %%
vocab

# %%
l3 = [x for x in vocab if x not in sentsss]

# %%
import pickle
# l = l3
# with open("test.txt", "wb") as fp:   #Pickling
#   pickle.dump(l, fp) 
with open("/content/drive/My Drive/hindiwords.txt", "rb") as fp:   # Unpickling
  b = pickle.load(fp)

# %%
b
# Out:
# ['Bhai',
#  '60sal',
#  'desh',
#  'pta',
#  'kro',
#  'waise',
#  'ka',
#  'chutiya',
#  'friday',
#  'releae',
#  'krte',
#  'kyoki',
#  '3',
#  'din',
#  'milte',
#  'h',
#  'log',
#  'hokr',
#  'dekh',
#  'sake..!!',
#  'hd',
#  'yrr',
#  'chutiyapa',
#  'जय',
#  'मोदीराज',
#  'UPA',
#  'walo',
#  'bahot',
#  'kr',
#  'k',
#  'Pan',
#  'Aadhar',
#  'zarurat',
#  'kuy',
#  'hai?',
#  'Court',
#  'bola',
#  'nahi',
#  'काकर',
#  'पाथर',
#  'जोड़',
#  'के',
#  'मस्जिद',
#  'लई',
#  'बनाय।\n\nता',
#  'चढ़ि',
#  'मुल्ला',
#  'बांघ',
#  'दे',
#  ',',
#  'क्या',
#  'बहरा',
#  'हुआ',
#  'खुदाय।',
#  '\n\nयह',
#  'मैं',
#  'नहीं',
#  'कबीर',
#  'ने',
#  'कहा',
#  'था।',
#  'Us',
#  'raat',
#  'tere',
#  'papa',
#  'jageh',
#  'mera',
#  'sperm',
#  'gya',
#  '\nAur',
#  'v',
#  'na',
#  'chala',
#  '😂😂😂\nChutiya',
#  'गटर',
#  'कीड़े',
#  'Waise',
#  'bandhu',
#  'lag',
#  'bachne',
#  'Raat',
#  '10',
#  'baje',
#  'jao',
#  '+91-(9815215009)',
# ...

# %%
b1 = [f for f in b if len(f) > 3]

# %%
for n, i in enumerate(b1):
  b1[n] = trn.transform(i)

# %%
len(b1)
# Out:
# 48493

# %%
l = b1

# %%
with open("hindiwords.txt", "wb") as fp:   #Pickling
  pickle.dump(l, fp)

# %%
len(b)
# Out:
# 53905

# %%
# !GetOldTweets3 --querysearch "bitcoin" --near "Berlin, Germany" --within 25km --maxtweets 10
# Out:
# ...
# Saved 10
# Done. Output file generated "output_got.csv".
